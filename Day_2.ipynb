# %%
import pandas as pd
from mlxtend.frequent_patterns import association_rules,apriori

# %%
dataset=pd.read_csv('groceries.csv')
dataset.head()
# Out:
#              Item 1               Item 2          Item 3  \
# 0      citrus fruit  semi-finished bread       margarine
# 1    tropical fruit               yogurt          coffee
# 2        whole milk                  NaN             NaN
# 3         pip fruit               yogurt   cream cheese
# 4  other vegetables           whole milk  condensed milk
#
#                      Item 4 Item 5 Item 6 Item 7 Item 8 Item 9 Item 10  ...  \
# 0               ready soups    NaN    NaN    NaN    NaN    NaN     NaN  ...
# 1                       NaN    NaN    NaN    NaN    NaN    NaN     NaN  ...
# 2                       NaN    NaN    NaN    NaN    NaN    NaN     NaN  ...
# 3              meat spreads    NaN    NaN    NaN    NaN    NaN     NaN  ...
# 4  long life bakery product    NaN    NaN    NaN    NaN    NaN     NaN  ...
#
#   Item 13 Item 14 Item 15 Item 16 Item 17 Item 18 Item 19 Item 20 Item 21  \
# 0     NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 1     NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 2     NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 3     NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 4     NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
#
#   Item 22
# 0     NaN
# 1     NaN
# 2     NaN
# 3     NaN
# 4     NaN
#
# [5 rows x 22 columns]

# %% [markdown]
# Preparing Transactions

# %%
dataset.shape
# Out:
# (9835, 22)

# %%
transactions = []
for i in range (0,9835):
  transactions.append([str(dataset.values[i,j])for j in range (0,22)])

# %%
from mlxtend.preprocessing import TransactionEncoder
te = TransactionEncoder()
te_transactions = te.fit_transform(transactions)
df = pd.DataFrame(te_transactions, columns = te.columns_)
df.head()
# Out:
#    Instant food products  UHT-milk  abrasive cleaner  artif. sweetener  \
# 0                  False     False             False             False
# 1                  False     False             False             False
# 2                  False     False             False             False
# 3                  False     False             False             False
# 4                  False     False             False             False
#
#    baby cosmetics  baby food   bags  baking powder  bathroom cleaner   beef  \
# 0           False      False  False          False             False  False
# 1           False      False  False          False             False  False
# 2           False      False  False          False             False  False
# 3           False      False  False          False             False  False
# 4           False      False  False          False             False  False
#
#    ...  turkey  vinegar  waffles  whipped/sour cream  whisky  white bread  \
# 0  ...   False    False    False               False   False        False
# 1  ...   False    False    False               False   False        False
# 2  ...   False    False    False               False   False        False
# 3  ...   False    False    False               False   False        False
# 4  ...   False    False    False               False   False        False
#
#    white wine  whole milk  yogurt  zwieback
# 0       False       False   False     False
# 1       False       False    True     False
# 2       False        True   False     False
# 3       False       False    True     False
# 4       False        True   False     False
#
# [5 rows x 170 columns]

# %% [markdown]
# Association Rule Learning

# %%
df = df.drop(columns = 'nan')

# %%
model = apriori(df,min_support = 0.03, use_colnames = True)
results = association_rules(model, metric = 'confidence', min_threshold = 0.3)
results.sort_values(by = 'lift', ascending = False)
# Out:
#              antecedents         consequents  antecedent support  \
# 2      (root vegetables)  (other vegetables)            0.108998
# 8              (sausage)        (rolls/buns)            0.093950
# 3       (tropical fruit)  (other vegetables)            0.104931
# 12  (whipped/sour cream)        (whole milk)            0.071683
# 10     (root vegetables)        (whole milk)            0.108998
# 5               (yogurt)  (other vegetables)            0.139502
# 11      (tropical fruit)        (whole milk)            0.104931
# 13              (yogurt)        (whole milk)            0.139502
# 7            (pip fruit)        (whole milk)            0.075648
# 4     (other vegetables)        (whole milk)            0.193493
# 6               (pastry)        (whole milk)            0.088968
# 1         (citrus fruit)        (whole milk)            0.082766
# 0        (bottled water)        (whole milk)            0.110422
# 9           (rolls/buns)        (whole milk)            0.183935
#
#     consequent support   support  confidence      lift  leverage  conviction  \
# 2             0.193493  0.047382    0.434701  2.246605  0.026291    1.426693
# 8             0.183935  0.030605    0.325758  1.771048  0.013324    1.210344
# 3             0.193493  0.035892    0.342054  1.767790  0.015589    1.225796
# 12            0.255516  0.032232    0.449645  1.759754  0.013916    1.352735
# 10            0.255516  0.048907    0.448694  1.756031  0.021056    1.350401
# 5             0.193493  0.043416    0.311224  1.608457  0.016424    1.170929
# 11            0.255516  0.042298    0.403101  1.577595  0.015486    1.247252
# 13            0.255516  0.056024    0.401603  1.571735  0.020379    1.244132
# 7             0.255516  0.030097    0.397849  1.557043  0.010767    1.236375
# 4             0.255516  0.074835    0.386758  1.513634  0.025394    1.214013
# 6             0.255516  0.033249    0.373714  1.462587  0.010516    1.188729
# 1             0.255516  0.030503    0.368550  1.442377  0.009355    1.179008
# 0             0.255516  0.034265    0.310313  1.214456  0.006051    1.079452
# 9             0.255516  0.056634    0.307905  1.205032  0.009636    1.075696
#
#     zhangs_metric
# 2        0.622764
# 8        0.480506
# 3        0.485239
# 12       0.465077
# 10       0.483202
# 5        0.439613
# 11       0.409045
# 13       0.422732
# 7        0.387036
# 4        0.420750
# 6        0.347166
# 1        0.334375
# 0        0.198506
# 9        0.208496

# %%
import matplotlib.pyplot as plt
plt.scatter(results['support'],results['confidence'],s = 100, color = 'red')
plt.xlabel('support')
plt.ylabel('confidence')
plt.title('support vs confidence')
for i, label in enumerate(results.index):
  plt.annotate(label, (results['support'][i], results['confidence'][i]))
plt.show()
